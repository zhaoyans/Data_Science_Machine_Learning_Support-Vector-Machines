# %% [markdown]
# # Zhaoyang Song
# # 9801611234
#
# # 1. Multi-class and Multi-Label Classification Using Support Vector Machines

# %% [markdown]
# ## (a) Download the Anuran Calls (MFCCs) Data Set from: https://archive.ics. uci.edu/ml/datasets/Anuran+Calls+%28MFCCs%29. Choose 70% of the data randomly as the training set.

# %%
import pandas as pd
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = pd.read_csv('Frogs_MFCCs.csv')
data
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# 5          1.0  0.099704 -0.033408  0.349895  0.344535  0.247569  0.022407
# 6          1.0  0.021676 -0.062075  0.318229  0.380439  0.179043 -0.041667
# 7          1.0  0.145130 -0.033660  0.284166  0.279537  0.175211  0.005791
# 8          1.0  0.271326  0.027777  0.375738  0.385432  0.272457  0.098192
# 9          1.0  0.120565 -0.107235  0.316555  0.364437  0.307757  0.025992
# 10         1.0  0.148539 -0.096910  0.257523  0.260881  0.312603  0.134134
# ...

# %%
training_data = data.sample(frac=0.7, replace=True, random_state=1)
training_data.reset_index(drop=True,inplace=True)
test_data = data.loc[~data.index.isin(training_data.index), :]
test_data.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## (b) Each instance has three labels: Families, Genus, and Species. Each of the labels has multiple classes. We wish to solve a multi-class and multi-label problem. One of the most important approaches to multi-class classification is to train a classifier for each label. We first try this approach:

# %%
y_training_1 = training_data[["Family"]]
y_training_2 = training_data[["Genus"]]
y_training_3 = training_data[["Species"]]
x_training = training_data.drop(["Family", "Genus", "Species", "RecordID"], axis=1)

y_test_1 = test_data[["Family"]]
y_test_2 = test_data[["Genus"]]
y_test_3 = test_data[["Species"]]
x_test = test_data.drop(["Family", "Genus", "Species", "RecordID"], axis=1)

# %% [markdown]
# ### i. Research exact match and hamming score/ loss methods for evaluating multi- label classification and use them in evaluating the classifiers in this problem.

# %%
from sklearn.metrics import hamming_loss
from sklearn import svm

# %% [markdown]
# 1.

# %%
clf = svm.SVC(gamma='auto')
model = clf.fit(x_training, y_training_1)

y_pred_1 = model.predict(x_test)

hamming_loss(y_test_1, y_pred_1)
# Out:
# 0.083371931449745251

# %%
pred_1 = pd.DataFrame(data=y_pred_1, columns=y_training_1.columns)
sum = 0
for i in range(0,len(pred_1)):
    if pred_1.values.tolist()[i][0] == y_training_1.values.tolist()[i][0]:
        sum +=1
exact_match = sum/len(pred_1)
exact_match
# Out:
# 0.3344140805928671

# %% [markdown]
# 2.

# %%
clf = svm.SVC(gamma='auto')
model = clf.fit(x_training, y_training_2)

y_pred_2 = model.predict(x_test)

hamming_loss(y_test_2, y_pred_2)
# Out:
# 0.1445113478462251

# %%
pred_2 = pd.DataFrame(data=y_pred_2, columns=y_training_2.columns)
sum = 0
for i in range(0,len(pred_2)):
    if pred_2.values.tolist()[i][0] == y_training_2.values.tolist()[i][0]:
        sum +=1
exact_match = sum/len(pred_2)
exact_match
# Out:
# 0.1954608615099583

# %% [markdown]
# 3.

# %%
clf = svm.SVC(gamma='auto')
model = clf.fit(x_training, y_training_3)

y_pred_3 = model.predict(x_test)

hamming_loss(y_test_3, y_pred_3)
# Out:
# 0.14729041222788328

# %%
pred_3 = pd.DataFrame(data=y_pred_3, columns=y_training_3.columns)
sum = 0
for i in range(0,len(pred_3)):
    if pred_3.values.tolist()[i][0] == y_training_3.values.tolist()[i][0]:
        sum +=1
exact_match = sum/len(pred_3)
exact_match
# Out:
# 0.11764705882352941

# %% [markdown]
# ### ii. Train a SVM for each of the labels, using Gaussian kernels and one versus all classifiers. Determine the weight of the SVM penalty and the width of the Gaussian Kernel using 10 fold cross validation.1 You are welcome to try to solve the problem with both standardized 2 and raw attributes and report the results.

# %% [markdown]
# #### Change the Parameter
# #### https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import svm
import numpy as np

gamma_svc = [0.1,1,10,100]
c_svc = [1,10,100,1000]

param_grid = dict(gamma=gamma_svc, C=c_svc)

clf_svc = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=10)

# %%
clf_svc.fit(x_training, y_training_1)
clf_svc.best_params_
# Out:
# {'C': 100, 'gamma': 1}

# %%
clf_svc.fit(x_training, y_training_2)
clf_svc.best_params_
# Out:
# {'C': 100, 'gamma': 1}

# %%
clf_svc.fit(x_training, y_training_3)
clf_svc.best_params_
# Out:
# {'C': 100, 'gamma': 1}

# %% [markdown]
# ### iii. Repeat 1(b)ii with L1-penalized SVMs.3 Remember to standardize4 the at- tributes. Determine the weight of the SVM penalty using 10 fold cross vali- dation.

# %%
from sklearn.svm import LinearSVC

c_svc = [1,10,100]
param_grid=dict(C=c_svc)

clf_l = GridSearchCV(LinearSVC(penalty='l1', dual=False), param_grid=param_grid, cv=10)
clf_l.fit(x_training, y_training_1)
clf_l.best_params_
# Out:
# {'C': 100}

# %%
clf_l.fit(x_training, y_training_2)
clf_l.best_params_
# Out:
# {'C': 100}

# %%
clf_l.fit(x_training, y_training_3)
clf_l.best_params_
# Out:
# {'C': 10}

# %% [markdown]
# ### iv. Repeat 1(b)iii by using SMOTE or any other method you know to remedy class imbalance. Report your conclusions about the classifiers you trained.

# %% [markdown]
# ###
# #### Since my laptop's enviroment path all messed up, I finished this question in another computer.
#
# #### The file is uploaded. See "HW5_IV"
# ####

# %% [markdown]
# # 2. K-Means Clustering on a Multi-Class and Multi-Label Data Set

# %% [markdown]
# #### Monte-Carlo Simulation: Perform the following procedures 50 times, and report the average and standard deviation of the 50 Hamming Distances that you calculate.

# %% [markdown]
# ### (a) Use k-means clustering on the whole Anuran Calls (MFCCs) Data Set (do not split the data into train and test, as we are not performing supervised learning in this exercise). Choose k ∈ {1, 2, . . . , 50} automatically based on one of the methods provided in the slides (CH or Gap Statistics or scree plots or Silhouettes) or any other method you know.

# %%
df=pd.read_csv("Frogs_MFCCs.csv")
df.drop('RecordID', axis=1, inplace=True)
df.head()
y=df[["Family","Genus","Species"]]
Family=y[["Family"]]
Genus=y[["Genus"]]
Species=y[["Species"]]
X=df.drop(["Family","Genus","Species"],axis=1)
X
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# 5          1.0  0.099704 -0.033408  0.349895  0.344535  0.247569  0.022407
# 6          1.0  0.021676 -0.062075  0.318229  0.380439  0.179043 -0.041667
# 7          1.0  0.145130 -0.033660  0.284166  0.279537  0.175211  0.005791
# 8          1.0  0.271326  0.027777  0.375738  0.385432  0.272457  0.098192
# 9          1.0  0.120565 -0.107235  0.316555  0.364437  0.307757  0.025992
# 10         1.0  0.148539 -0.096910  0.257523  0.260881  0.312603  0.134134
# ...

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabaz_score,silhouette_score
import statistics

# %%
unmclusters=np.arange(2,10)
results={}
for i in num_clusters:
    model=KMeans(n_clusters=i).fit(X)
    predictions=model.predict(X)
    results[i]=silhouette_score(X,predictions)
cluster=max(results,key=results.get)
print(cluster)
# Out:
# 4

# %% [markdown]
# ### (b) In each cluster, determine which family is the majority by reading the true labels. Repeat for genus and species.

# %%
kmeans=KMeans(n_clusters=4).fit(X)
clusters=kmeans.labels_
index0 = np.argwhere(clusters == 0)
index1 = np.argwhere(clusters == 1)
index2 = np.argwhere(clusters == 2)
index3 = np.argwhere(clusters == 3)
family1=pd.DataFrame(columns=['Family'])
g1=pd.DataFrame(columns=['Genus'])
s1=pd.DataFrame(columns=['Species'])

family2=pd.DataFrame(columns=['Family'])
g2=pd.DataFrame(columns=['Genus'])
s2=pd.DataFrame(columns=['Species'])

family3=pd.DataFrame(columns=['Family'])
g3=pd.DataFrame(columns=['Genus'])
s3=pd.DataFrame(columns=['Species'])

family4=pd.DataFrame(columns=['Family'])
g4=pd.DataFrame(columns=['Genus'])
s4=pd.DataFrame(columns=['Species'])

index0=pd.DataFrame(index0)
index1=pd.DataFrame(index1)
index2=pd.DataFrame(index2)
index3=pd.DataFrame(index3)

index0.count()
index1.count()
index2.count()
index3.count()
# Out:
# 0    610
# dtype: int64

# %% [markdown]
# ### (c) Now for each cluster you have a majority label triplet (family, genus, species). Calculate the average Hamming distance, Hamming score, and Hamming loss5 between the true labels and the labels assigned by clusters.

# %%
from sklearn.metrics import hamming_loss
pred=kmeans.predict(X)
pf=pred
pg=pred
ps=pred

new_family=pd.DataFrame(pf,columns=Family.columns)
new_genus=pd.DataFrame(pg,columns=Genus.columns)
new_species=pd.DataFrame(ps,columns=Species.columns)

new_family=new_family.replace((0,1,2,3),('Leptodactylidae ',' Leptodactylidae','Hylidae ','Leptodactylidae '))
new_genus=new_genus.replace((0,1,2,3),('Adenomera ','Adenomera ','Hypsiboas','Hypsiboas'))
new_species=new_species.replace((0,1,2,3),('AdenomeraHylaedactylus ','AdenomeraHylaedactylus','HypsiboasCordobae','HypsiboasCinerascens'))

family_hscore=hamming_loss(Family,new_family)
print("The hamming score for family is", family_hscore)

genus_hscore=hamming_loss(Genus,new_genus)
print("The hamming score for genus is", genus_hscore)

species_hscore=hamming_loss(Species,new_species)
print("The hamming score for species is", species_hscore)
# Out:
# The hamming score for family is 1.0
# The hamming score for genus is 0.780403057679
# The hamming score for species is 0.795691452397

# %% [markdown]
# # 3. ISLR 10.7.2

# %% [markdown]
# Suppose that we have four observations, for which we compute a dissimilarity matrix, given by
#        0.3 0.4  0.7
#    0.3     0.5  0.8
#    0.4 0.5      0.45
#    0.7 0.8 0.45
#
# For instance, the dissimilarity between the first and second observations is 0.3, and the dissimilarity betweenthe second and fourth observations is 0.8.

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# (a) On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observa- tions using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
dataset = np.array([[0, 0.3, 0.4, 0.7],
              [0.3, 0, 0.5, 0.8],
              [0.4, 0.5, 0, 0.45],
              [0.7, 0.8, 0.45, 0]])
Z = linkage(dataset, 'complete')
dn = dendrogram(Z)
plt.show()

# %% [markdown]
# (b) Repeat (a), this time using single linkage clustering.

# %%
Z = linkage(dataset, 'single')
dn = dendrogram(Z)
plt.show()

# %% [markdown]
# (c) Suppose that we cut the dendogram obtained in (a) such that two clusters result. Which observations are in each cluster?
#
# solution: (0,1) and (2,3)

# %% [markdown]
# (d) Suppose that we cut the dendogram obtained in (b) such that two clusters result. Which observations are in each cluster?
#
# solution: ((0,1),2) and (3)

# %% [markdown]
# (e) It is mentioned in the chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
from IPython.display import Image
Image(filename='e.png')
